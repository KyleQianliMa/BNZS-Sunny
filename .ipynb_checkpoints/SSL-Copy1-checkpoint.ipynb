# %%
# === Loading Packages ===
using Sunny # The main package
using ProgressMeter  #Statistics, Formatting, StaticArrays, LinearAlgebra, DelimitedFiles, OffsetArrays, Random # Some useful peripheral packages
using GLMakie, Plots # Some useful plotting packages
using Statistics, Formatting, StaticArrays, LinearAlgebra, DelimitedFiles, OffsetArrays, JLD2, Random
Sunny.offline_viewers();

# %%
# === Define the crystal structure of SSL by importing a cif file === 
xtal_SSL = Crystal("SSL.cif",symprec=0.001);
display(xtal_SSL);
# Out:
# Crystal
# HM symbol 'I -4 2 m' (121)
# Lattice params a=8.985, b=8.985, c=6.641, α=90°, β=90°, γ=90°
# Cell volume 536.1
# Type 'Sr1', Wyckoff 4c (point group '222.'):
#    1. [0.5, 0, 0]
#    2. [0, 0.5, 0]
#    3. [0.5, 0, 0.5]
#    4. [0, 0.5, 0.5]
# Type 'Cu1', Wyckoff 8i (point group '..m'):
#    5. [0.6153, 0.3846, 0.2105]
#    6. [0.3846, 0.6153, 0.2105]
#    7. [0.1154, 0.1154, 0.2895]
#    8. [0.8846, 0.8846, 0.2895]
#    9. [0.8846, 0.1154, 0.7105]
#    10. [0.1154, 0.8846, 0.7105]
#    11. [0.3846, 0.3846, 0.7895]
#    12. [0.6153, 0.6153, 0.7895]
# Type 'B1', Wyckoff 8i (point group '..m'):
#    13. [0.295, 0.295, 0.2386]
#    14. [0.705, 0.705, 0.2386]
#    15. [0.795, 0.205, 0.2614]
#    16. [0.205, 0.795, 0.2614]
#    17. [0.205, 0.205, 0.7386]
#    18. [0.795, 0.795, 0.7386]
#    19. [0.705, 0.295, 0.7614]
#    20. [0.295, 0.705, 0.7614]
# Type 'O1', Wyckoff 8i (point group '..m'):
#    21. [0.4008, 0.4008, 0.1973]
#    22. [0.5992, 0.5992, 0.1973]
#    23. [0.9008, 0.0992, 0.3027]
#    24. [0.0992, 0.9008, 0.3027]
#    25. [0.0992, 0.0992, 0.6973]
#    26. [0.9008, 0.9008, 0.6973]
#    27. [0.5992, 0.4008, 0.8027]
#    28. [0.4008, 0.5992, 0.8027]
# Type 'O2', Wyckoff 16j (point group '1'):
#    29. [0.646, 0.1719, 0.2409]
#    30. [0.8281, 0.354, 0.2409]
#    31. [0.1719, 0.646, 0.2409]
#    32. [0.354, 0.8281, 0.2409]
#    33. [0.3281, 0.146, 0.2591]
#    34. [0.146, 0.3281, 0.2591]
#    35. [0.854, 0.6719, 0.2591]
#    36. [0.6719, 0.854, 0.2591]
#    37. [0.6719, 0.146, 0.7409]
#    38. [0.854, 0.3281, 0.7409]
#    39. [0.146, 0.6719, 0.7409]
#    40. [0.3281, 0.854, 0.7409]
#    41. [0.354, 0.1719, 0.7591]
#    42. [0.1719, 0.354, 0.7591]
#    43. [0.8281, 0.646, 0.7591]
#    44. [0.646, 0.8281, 0.7591]

# %%
xtal=subcrystal(xtal_SSL, "Cu1",)
# Out:
# Warning: atoms are being renumbered.
# Crystal
# HM symbol 'I -4 2 m' (121)
# Lattice params a=8.985, b=8.985, c=6.641, α=90°, β=90°, γ=90°
# Cell volume 536.1
# Type 'Cu1', Wyckoff 8i (point group '..m'):
#    1. [0.6153, 0.3846, 0.2105]
#    2. [0.3846, 0.6153, 0.2105]
#    3. [0.1154, 0.1154, 0.2895]
#    4. [0.8846, 0.8846, 0.2895]
#    5. [0.8846, 0.1154, 0.7105]
#    6. [0.1154, 0.8846, 0.7105]
#    7. [0.3846, 0.3846, 0.7895]
#    8. [0.6153, 0.6153, 0.7895]

# %%
L = 4
k=4
sys = System(xtal, (L,L,k), [SpinInfo(1, S=1/2, g=1)], :SUN, units=Units.theory, seed=0)
# Out:
# System [SU(2)]
# Cell size 8, Lattice size (4, 4, 4)

# %%
set_exchange!(sys, 0, Bond(1,2,(0,0,0))) #intra dimer J
set_exchange!(sys, 1, Bond(3,1,(0,0,0))) #inter dimer J'

# %%
print_symmetry_table(xtal,5.2)
# Out:
# Atom 1
# Type 'Cu1', position [0.6153, 0.3846, 0.2105], multiplicity 8
# Allowed g-tensor: |   A    D  C-E |
#                   |   D    A -C+E |
#                   | C+E -C-E    B |
# Allowed anisotropy in Stevens operators 𝒪[k,q]:
#     c₁*𝒪[2,-2] + c₂*𝒪[2,0] + c₃*(-𝒪[2,-1]+𝒪[2,1]) +
#     c₄*𝒪[4,-2] + c₅*𝒪[4,0] + c₆*(𝒪[4,-1]-𝒪[4,1]) + c₇*(𝒪[4,-3]+𝒪[4,3]) + c₈*𝒪[4,4] +
#     c₉*𝒪[6,-6] + c₁₀*𝒪[6,-2] + c₁₁*𝒪[6,0] + c₁₂*(-𝒪[6,-1]+𝒪[6,1]) + c₁₃*(𝒪[6,-3]+𝒪[6,3]) + c₁₄*𝒪[6,4] + c₁₅*(𝒪[6,-5]-𝒪[6,5])
#
# Bond(1, 2, [0, 0, 0])
# Distance 2.93141489538785, coordination 1
# Connects 'Cu1' at [0.6153, 0.3846, 0.2105] to 'Cu1' at [0.3846, 0.6153, 0.2105]
# Allowed exchange matrix: | A  C -D |
#                          | C  A  D |
#                          | D -D  B |
# Allowed DM vector: [D D 0]
#
# Bond(3, 5, [-1, 0, 0])
# Distance 3.48049358287552, coordination 2
# Connects 'Cu1' at [0.1154, 0.1154, 0.2895] to 'Cu1' at [-0.1153, 0.1154, 0.7105]
# Allowed exchange matrix: | A  F  D |
#                          |-F  B  E |
#                          | D -E  C |
# Allowed DM vector: [E 0 F]
#
# Bond(1, 7, [0, 0, 0])
# Distance 4.36834608719637, coordination 2
# Connects 'Cu1' at [0.6153, 0.3846, 0.2105] to 'Cu1' at [0.3846, 0.3846, 0.7895]
# Allowed exchange matrix: | A  F  D |
#                          |-F  B  E |
#                          | D -E  C |
# Allowed DM vector: [E 0 F]
#
# Bond(5, 1, [0, 0, 0])
# Distance 4.76818793268217, coordination 2
# Connects 'Cu1' at [0.8846, 0.1154, 0.7105] to 'Cu1' at [0.6153, 0.3846, 0.2105]
# Allowed exchange matrix: |   A    D  C-E |
#                          |   D    A -C+E |
#                          | C+E -C-E    B |
# Allowed DM vector: [E E 0]
#
# Bond(3, 1, [0, 0, 0])
# Distance 5.12953873736278, coordination 4
# Connects 'Cu1' at [0.1154, 0.1154, 0.2895] to 'Cu1' at [0.6153, 0.3846, 0.2105]
# Allowed exchange matrix: |   A  F+I  E-H |
#                          | F-I    B  D+G |
#                          | E+H  D-G    C |
# Allowed DM vector: [G H I]

# %%
sys=to_inhomogeneous(sys)
for i in range(start = 1, stop=L, step=1)
    for j in range(start = 1, stop=L, step=1)
        for k in range(start = 1, stop=k, step=1)
              set_vacancy_at!(sys,(i,j,k,5))
              set_vacancy_at!(sys,(i,j,k,6))
              set_vacancy_at!(sys,(i,j,k,7))
              set_vacancy_at!(sys,(i,j,k,8))

        end
    end
end
plot_spins(sys, arrowsize=1)
# Out:
# Figure()

# %%
Δt = 0.01
λ = 0.1        # Dimensionless magnitude of coupling to thermal bath
langevin = Langevin(Δt; kT=0, λ);
randomize_spins!(sys)

# %%
for kT in range(1, 0, 200_000)
    langevin.kT = kT
    step!(sys, langevin)
end
plot_spins(sys,arrowlength=0.5, linewidth=0.5, arrowsize=1.0)
# Out:
# Figure()

# %%
# # Make a `StructureFactor` and calculate an initial sample
# sf = DynamicStructureFactor(sys; Δt=0.01, ωmax=5.0, nω=100);

# %%
# kT=0.025
# points = [[0,   0, 0],  # List of wave vectors that define a path
#           [-2.5,   0, 0],]
# density = 80
# path, markers = connected_path(points, density);

# formfactors = [FormFactor(1, "Nd3"; g_lande=0.78)]
# is = intensities(sf, path, :perp;
#     interpolation = :linear,       # Interpolate between available wave vectors
#     kT,                            # Temperature for intensity correction
#     formfactors,                   # Form factor information
# )
# is = broaden_energy(sf, is, (ω, ω₀)->lorentzian(ω-ω₀, 0.01))  # Add artificial broadening

# labels = ["($(p[1]),$(p[2]),$(p[3]))" for p in points]

# GLMakie.heatmap(1:size(is,1), ωs(sf), is;
#     colorrange=(0, 0.1),
#     axis = (
# #         ylabel = "meV",
#         xticks = (markers, labels),
#         xticklabelrotation=π/8,
#         xticklabelsize=12,
#     )
# )
# Out:
# FigureAxisPlot()
